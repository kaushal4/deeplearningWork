# %%
import tensorflow as tf

# %%
from tensorflow import keras
import matplotlib.pyplot as plt 
# %matplotlib inline
import numpy as np

# %%
(x_train,y_train),(x_test,y_test)= keras.datasets.mnist.load_data()

# %%
len(x_train)
# Out:
# 60000

# %%
type(x_train)
# Out:
# numpy.ndarray

# %%
x_train[0].shape
# Out:
# (28, 28)

# %%
plt.matshow(x_train[0])

# %%
x_train_flattened=x_train.reshape(len(x_train),28*28)
x_test_flattened = x_test.reshape(len(x_test),28*28)

# %%
x_train_flattened.shape
# Out:
# (60000, 784)

# %%
x_train_flattened = x_train_flattened/255
x_test_flattened = x_test_flattened/255

# %%
model = keras.Sequential([keras.layers.Dense(10,input_shape=(784,),activation="sigmoid")])

model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

model.fit(x_train_flattened,y_train,epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.7289 - accuracy: 0.8065
# Epoch 2/5
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3097 - accuracy: 0.9133
# Epoch 3/5
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2823 - accuracy: 0.9212
# Epoch 4/5
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2738 - accuracy: 0.9237
# Epoch 5/5
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2665 - accuracy: 0.9275

# %%
model.evaluate(x_test_flattened, y_test)
# Out:
# 313/313 [==============================] - 0s 965us/step - loss: 0.2710 - accuracy: 0.9242
# [0.2709669768810272, 0.9241999983787537]

# %%
plt.matshow(x_test[2])

# %%
y_predicted = model.predict(x_test_flattened)
print(np.argmax(y_predict[2]))
# Out:
# 1

# %%
y_predicted_labels = [np.argmax(i) for i in y_predicted]

# %%
cm = tf.math.confusion_matrix(labels=y_test,predictions=y_predicted_labels)
cm
# Out:
# <tf.Tensor: shape=(10, 10), dtype=int32, numpy=
# array([[ 956,    0,    0,    2,    0,    5,   12,    2,    3,    0],
#        [   0, 1112,    3,    2,    0,    1,    4,    2,   11,    0],
#        [   4,   10,  904,   21,    8,    4,   14,   10,   54,    3],
#        [   3,    1,   15,  915,    1,   19,    3,   13,   35,    5],
#        [   1,    1,    2,    1,  921,    0,   13,    4,   11,   28],
#        [   8,    3,    1,   36,   11,  764,   17,    8,   39,    5],
#        [   7,    3,    4,    1,    7,    9,  920,    2,    5,    0],
#        [   1,    5,   20,    7,    7,    0,    0,  952,    6,   30],
#        [   5,    7,    6,   15,    9,   19,   10,    9,  889,    5],
#        [  10,    6,    1,   10,   33,    4,    0,   22,   14,  909]])>

# %%
import seaborn as sn
plt.figure(figsize=(10,7))
sn.heatmap(cm,annot=True,fmt="d")
plt.xlabel("Predicted")
plt.ylabel("truth")
# Out:
# Text(69.0, 0.5, 'truth')

# %%
model = keras.Sequential([
    keras.layers.Dense(100,input_shape=(784,),activation="relu"),
    keras.layers.Dense(10,activation="sigmoid")])

model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

model.fit(x_train_flattened,y_train,epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.4568 - accuracy: 0.8738
# Epoch 2/5
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1302 - accuracy: 0.9624
# Epoch 3/5
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0866 - accuracy: 0.9748
# Epoch 4/5
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0652 - accuracy: 0.9806
# Epoch 5/5
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0477 - accuracy: 0.9860

# %%
model.evaluate(x_test_flattened,y_test)
# Out:
# 313/313 [==============================] - 0s 827us/step - loss: 0.0797 - accuracy: 0.9766
# [0.07966791093349457, 0.9765999913215637]

# %%
import seaborn as sn
plt.figure(figsize=(10,7))
sn.heatmap(cm,annot=True,fmt="d")
plt.xlabel("Predicted")
plt.ylabel("truth")
# Out:
# Text(69.0, 0.5, 'truth')

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28,28)),
    keras.layers.Dense(100,activation="relu"),
    keras.layers.Dense(10,activation="sigmoid")])

model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

model.fit(x_train/255,y_train,epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4565 - accuracy: 0.8720
# Epoch 2/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1273 - accuracy: 0.9633
# Epoch 3/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0921 - accuracy: 0.9726
# Epoch 4/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0672 - accuracy: 0.9797
# Epoch 5/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0525 - accuracy: 0.9843
